# %%
import pandas as pd
from datetime import datetime, timedelta
from pandas import Index
import numpy as np
from pytrends import request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pytrends.request import TrendReq

# %%
pm25_path    = "data/20180101_20180806-PA04C_auto.csv"
table=pd.read_csv(pm25_path ,sep=';').drop(0,axis=0)
table=table.rename(mapper={'heure':'hour'},axis=1)
table['date time'] = list(map(lambda stringdate,
         dhour: datetime.strptime(stringdate,'%d/%m/%Y').replace(hour=int(dhour)-1),
         table['date'],table['hour']))

# %%
def str2int(mstr):
    if mstr == 'n/d':
        return None
    else: return int(mstr)
table['PM25']=list(map(lambda mstr: str2int(mstr),table['PM25']))

# %%
table.to_csv("tempairparif.csv")

# %%
newest_datetime   = max(table['date time'])
earliest_datetime = min(table['date time'])

# %%
earliest_datetime
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# ggtrend
pytrends = TrendReq(hl='En-US', tz=-120)
kw_list =  [pytrends.suggestions("air pollution")[0]['mid'],'air pollution']

# %%
ggtrend = pytrends.get_historical_interest(kw_list, 
                                 year_start=earliest_datetime.year,
                                          month_start=earliest_datetime.month, 
                                          day_start=earliest_datetime.days_in_month, 
                                          hour_start=earliest_datetime.hour, 
                                 year_end=newest_datetime.year,
                                          month_end=newest_datetime.month, 
                                          day_end=newest_datetime.days_in_month, 
                                          hour_end=newest_datetime.hour, 
                                 cat=0, # all categorical
                                          geo='FR-J',  # france ile-defrance
                                          gprop='',  # no specific group # image #hastag etc
                                          sleep=0)
# Out:
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.

# %%
ggtrend.head()
# Out:
#                      /m/0dc7h  air pollution isPartial
# date
# 2018-01-31 00:00:00        35             17     False
# 2018-01-31 01:00:00        30             30     False
# 2018-01-31 02:00:00        43              0     False
# 2018-01-31 03:00:00         0              0     False
# 2018-01-31 04:00:00         0              0     False

# %%
ggtrend.reset_index(inplace=True)

# %%
ggtrend.columns=Index(['date time', 'air pollution topic','air pollution key word','isPartial'], dtype='object')

# %%
merged_t=table.merge(ggtrend,left_on='date time',right_on='date time')

# %%
merged_t=merged_t.fillna(method='ffill')

# %%
merged_t['air pollution topic']=merged_t['air pollution topic'].astype(np.int8)

# %%
date_index=(datetime(year=2018,month=6,day=15)< 
            merged_t['date time']) & (merged_t['date time']<datetime(year=2018,month=8,day=8))

# %% [markdown]
# # cross-correlation

# %%
def df_derived_by_shift(df,lag=0,NON_DER=[]):
    df = df.copy()
    if not lag:
        return df
    cols ={}
    for i in range(1,lag+1):
        for x in list(df.columns):
            if x not in NON_DER:
                if not x in cols:
                    cols[x] = ['{}_{}'.format(x, i)]
                else:
                    cols[x].append('{}_{}'.format(x, i))
    for k,v in cols.items():
        columns = v
        dfn = pd.DataFrame(data=None, columns=columns, index=df.index)    
        i = 1
        for c in columns:
            dfn[c] = df[k].shift(periods=i)
            i+=1
        df = pd.concat([df, dfn], axis=1, join_axes=[df.index])
    return df

# %%
cross_correlation=merged_t.loc[:,['air pollution topic','air pollution key word','PM25']]

# %%
cross_correlation.to_csv("temp_parif.csv")

# %%
new_cross=df_derived_by_shift(cross_correlation,lag=6)

# %%
new_cross = new_cross.dropna()

# %%
new_cross.head()
# Out:
#     air pollution topic  air pollution key word  PM25  air pollution topic_1  \
# 6                    68                      26   6.0                   92.0
# 7                    31                      26   4.0                   68.0
# 8                    40                      11   7.0                   31.0
# 9                    46                      22   7.0                   40.0
# 10                   29                       3   2.0                   46.0
#
#     air pollution topic_2  air pollution topic_3  air pollution topic_4  \
# 6                     0.0                    0.0                   43.0
# 7                    92.0                    0.0                    0.0
# 8                    68.0                   92.0                    0.0
# 9                    31.0                   68.0                   92.0
# 10                   40.0                   31.0                   68.0
#
#     air pollution topic_5  air pollution topic_6  air pollution key word_1  \
# 6                    30.0                   35.0                      92.0
# 7                    43.0                   30.0                      26.0
# 8                     0.0                   43.0                      26.0
# 9                     0.0                    0.0                      11.0
# 10                   92.0                    0.0                      22.0
#
#      ...    air pollution key word_3  air pollution key word_4  \
# 6    ...                         0.0                       0.0
# 7    ...                         0.0                       0.0
# 8    ...                        92.0                       0.0
# 9    ...                        26.0                      92.0
# 10   ...                        26.0                      26.0
#
#     air pollution key word_5  air pollution key word_6  PM25_1  PM25_2  \
# 6                       30.0                      17.0     7.0     8.0
# 7                        0.0                      30.0     6.0     7.0
# 8                        0.0                       0.0     4.0     6.0
# 9                        0.0                       0.0     7.0     4.0
# 10                      92.0                       0.0     7.0     7.0
#
#     PM25_3  PM25_4  PM25_5  PM25_6
# 6      6.0     5.0     6.0     7.0
# 7      8.0     6.0     5.0     6.0
# 8      7.0     8.0     6.0     5.0
# 9      6.0     7.0     8.0     6.0
# 10     4.0     6.0     7.0     8.0
#
# [5 rows x 21 columns]

# %%
# from sklearn.preprocessing import scale

# %%
df_new =new_cross

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,10))
plt.title(u'6 hours', y=1.05, size=16)

mask = np.zeros_like(df_new.corr())
mask[np.triu_indices_from(mask)] = True

svm = sns.heatmap(df_new.corr(), mask=mask, linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
plt.show()

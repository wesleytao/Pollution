# %%
import pandas as pd
import numpy as np
from pandas import Index
from datetime import datetime
import sys
sys._enablelegacywindowsfsencoding()

# %%
# %load_ext pycodestyle_magic

# %%
def signal_process(table,event_var='PM25_Marseille_Longchamp',event_threshold = 40, duration = 6,var_name_list='air pollution'):
    """Find the spike in pm25 and plot a sliding window for google trend """

    index_list=np.where(table[event_var]>event_threshold)[0]
    
    # add first element
    shrink_index_list = [index_list[0]]
    date_set ={table.date[index_list[0]]}
    
    # exclude for the same day
    for cnt in range(1,len(index_list)):
        if table.date[index_list[cnt]] in date_set:
            pass
        else:
            shrink_index_list.append(index_list[cnt].copy())
            date_set.add(table.date[index_list[cnt]])
    
    bind_list = []
    for start_index in shrink_index_list:
        this_sequence = table.loc[range(start_index-2,start_index+duration),
                                  var_name_list]
        start_date = table.datetime[start_index]
        tuples = list(zip([start_date]*(duration+2),range(-2,duration)))

        this_sequence.index = pd.MultiIndex.from_tuples(tuples,names=['event_date_index','hour_index'])
    #         this_sequence = (this_sequence- this_sequence.mean())/this_sequence.std()

        bind_list.append(this_sequence)
    new_table=pd.concat(bind_list)     
    
    return new_table

# %%
parca_table=pd.read_csv("../stage/parca_difficultés respiratoires_asthme_dyspnée_respiration_PM25_Marseille_Longchamp.csv",encoding='utf-8')

# %%
parca_table.columns=Index(['Unnamed: 0', 'datetime', 'PM25_Marseille_Longchamp', 'date',
       'difficultés respiratoires', 'difficultés respiratoires topic', 'isPartial', 'asthme',
       'asthme topic', 'isPartial.1', 'dyspnée', 'dyspnée topic', 'isPartial.2',
       'respiration', 'respiration topic', 'isPartial.3'],
      dtype='object')

# %%
keyword_list = ['PM25_Marseille_Longchamp', 'difficultés respiratoires', 'difficultés respiratoires topic', 'asthme',
       'asthme topic', 'dyspnée', 'dyspnée topic',  'respiration', 'respiration topic']

# %%
# datetime.strptime('2017-08-31 00:00:00',"%Y-%m-%d %H:%M:%S").date()

# %%
parca_table.date=list(map(lambda stringdate: datetime.strptime(stringdate,"%Y-%m-%d %H:%M:%S").date(),parca_table.datetime))

# %%
>>> df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
...                           'foo', 'bar'],
...                    'B' : [1, 2, 3, 4, 5, 6],
...                    'C' : [2.0, 5., 8., 1., 2., 9.]})
>>> grouped = df.groupby('A')
>>> grouped.filter(lambda x: np.all(x['B'] > 3.))
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
parca_table.groupby("date").filter(lambda x: np.all(x['PM25_Marseille_Longchamp']<35))
# Out:
#       Unnamed: 0             datetime  PM25_Marseille_Longchamp        date  \
# 0              0  2017-08-31 00:00:00                       8.0  2017-08-31
# 1              1  2017-08-31 01:00:00                       9.0  2017-08-31
# 2              2  2017-08-31 02:00:00                       8.0  2017-08-31
# 3              3  2017-08-31 03:00:00                       7.0  2017-08-31
# 4              4  2017-08-31 04:00:00                       8.0  2017-08-31
# 5              5  2017-08-31 05:00:00                       6.0  2017-08-31
# 6              6  2017-08-31 06:00:00                       6.0  2017-08-31
# 7              7  2017-08-31 07:00:00                      11.0  2017-08-31
# 8              8  2017-08-31 08:00:00                       8.0  2017-08-31
# 9              9  2017-08-31 09:00:00                       3.0  2017-08-31
# 10            10  2017-08-31 10:00:00                       9.0  2017-08-31
# 11            11  2017-08-31 11:00:00                      11.0  2017-08-31
# 5                             0                                0      False
# 6                             0                               20      False
# 7                             0                               21      False
# 8                             0                               25      False
# 9                             0                               12      False
# 10                            0                                0      False
# 11                            0                               19      False
# 12                            0                               30      False
# 13                            0                                6      False
# 14                            0                               18      False
# 15                            0                                0      False
# 16                            0                               12      False
# 17                            0                                7      False
# 18                            0                                7      False
# 19                            0                                6      False
# 20                            0                               56      False
# 21                            0                               10      False
# 22                            0                               33      False
# 23                            0                                0      False
# 48                            0                                0      False
# 49                            0                                0      False
# 50                            0                                0      False
# 51                            0                               82      False
# 52                            0                                0      False
# 53                            0                                0      False
# ...                         ...                              ...        ...
# 8082                          0                               20      False
# 8083                          0                               18      False
# 8084                          0                               15      False
# 8085                          0                                0      False
# 8086                          0                                0      False
# 8087                          0                               74      False
# 8088                          0                                0      False
# 8089                          0                                0      False
# 8090                          0                               30      False
# 8091                          0                               15      False
# 8092                          0                                9      False
# 8093                          0                               14      False
# 8094                          0                                6      False
# 8095                          0                               24      False
# 8096                          0                                0      False
# 8097                          0                               12      False
# 8098                          0                               17      False
# 8099                          0                               11      False
# 8100                          0                               12      False
# 8101                          0                               24      False
# 8102                          0                               12      False
# 8103                          0                               13      False
# 8104                          0                               20      False
# 8105                          0                               26      False
# 8106                          0                               14      False
# 8107                          0                               19      False
# 8108                          0                               30      False
# 8109                          0                               54      False
# 8110                          0                               46      False
# 8111                          0                                0      False
#
#       asthme  asthme topic  isPartial.1  dyspnée  dyspnée topic  isPartial.2  \
# 0         19            38        False        0             53        False
# 1          0             0        False        0             80        False
# 2          0            66        False       47             93        False
# 3          0             0        False        0              0        False
# 4          0             0        False        0             18        False
# 5         12            12        False        0             17        False
# 6          4            11        False        0             10        False
# 7          5            11        False        8              8        False
# 8          7            12        False       10             17        False
# 9          5             5        False        3              6        False
# 10         0             0        False        4              7        False
# 11         7             9        False        7             17        False
# 12         7             9        False        3              6        False
# 13        11            20        False        0              3        False
# 14         5             7        False        6             13        False
# 15         9            16        False        0             10        False
# 16        12            14        False        0              3        False
# 17         7            10        False        0              0        False
# 18        10            18        False        0             18        False
# 19         5             7        False        7             10        False
# 20         8            13        False        7              7        False
# 21        11            15        False        5              5        False
# 22         6            12        False        0             26        False
# 23        22            33        False        0              0        False
# 48         0             0        False        0              0        False
# 49         0             0        False        0              0        False
# 50        35            70        False        0              0        False
# 51         0             0        False        0              0        False
# 52        18            54        False        0              0        False
# 53         8             8        False        0              0        False
# ...      ...           ...          ...      ...            ...          ...
# 8082      25            29        False        0              0        False
# 8083       6            14        False        5              9        False
# 8084       5            18        False        0              0        False
# 8085      25            25        False        0             14        False
# 8086       0            15        False        0             25        False
# 8087      23            23        False        0              0        False
# 8088       0            28        False        0             91        False
# 8089       0             0        False        0              0        False
# 8090      28            28        False        0             15        False
# 8091       9            14        False        8              8        False
# 8092      14            20        False        5             10        False
# 8093       2            11        False       11             39        False
# 8094       6            10        False        6             19        False
# 8095       4             6        False        0              9        False
# 8096       0             4        False        0             17        False
# 8097      11            15        False        3              6        False
# 8098       5            16        False        0              3        False
# 8099       4             5        False        6             21        False
# 8100       2             7        False        3              6        False
# 8101      11            17        False        3             16        False
# 8102       4            14        False        0              6        False
# 8103       8            12        False        0              0        False
# 8104       8            10        False        0              7        False
# 8105       2            10        False        0              3        False
# 8106      11            20        False        0              4        False
# 8107       9            26        False        5             15        False
# 8108       9            19        False        0              8        False
# 8109       0            17        False        0             14        False
# 8110      29            43        False        0              0        False
# 8111       0             0        False        0             24        False
#
#       respiration  respiration topic  isPartial.3
# 0               0                 63        False
# 1              42                 96        False
# 2              25                 62        False
# 3              37                 55        False
# 4              14                 48        False
# 5               5                  9        False
# 6               6                 14        False
# 7               3                  9        False
# 8               6                 16        False
# 9               9                 19        False
# 10              2                  9        False
# 11              6                 18        False
# 12              3                  8        False
# 13              6                 16        False
# 14              3                 13        False
# 15              6                 18        False
# 16              4                 11        False
# 17              5                 14        False
# 18              8                 16        False
# 19              7                 17        False
# 20              8                 15        False
# 21              8                 21        False
# 22              7                 18        False
# 23              8                 29        False
# 48              0                 19        False
# 49             10                 31        False
# 50              0                 26        False
# 51             12                 35        False
# 52              7                 20        False
# 53              9                 39        False
# ...           ...                ...          ...
# 8082           16                 30        False
# 8083           17                 33        False
# 8084            5                 14        False
# 8085            8                 42        False
# 8086           15                 30        False
# 8087           23                 46        False
# 8088           14                 28        False
# 8089           10                 31        False
# 8090           14                 32        False
# 8091            5                 12        False
# 8092           12                 27        False
# 8093            8                 23        False
# 8094            4                 14        False
# 8095            7                 13        False
# 8096            5                 14        False
# 8097           12                 18        False
# 8098            7                 20        False
# 8099           11                 27        False
# 8100            5                 14        False
# 8101            3                 17        False
# 8102           11                 19        False
# 8103            4                 16        False
# 8104            1                 12        False
# 8105           12                 34        False
# 8106           10                 30        False
# 8107           12                 34        False
# 8108            9                 40        False
# 8109            8                 55        False
# 8110           14                 43        False
# 8111            9                 17        False
#
# [6352 rows x 16 columns]

# %%
new_parca=signal_process(parca_table,event_threshold=35,duration=12,var_name_list=keyword_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-f1933f38277b> in <module>()
# ----> 1 new_parca=signal_process(parca_table,event_threshold=35,duration=12,var_name_list=keyword_list)
#
# NameError: name 'signal_process' is not defined

# %%
new_parca.to_csv("../output/new_parca.csv")

# %%
parif_table = pd.read_csv("../stage/parif_difficultés respiratoires_asthme_dyspnée_respiration_PA04C_PM10.csv")

# %%
parif_kw = ['PA04C_PM25',
            'PA04C_PM10',
            'PA04C_O3',
            'PA04C_NO2',
            'PA04C_CO',
            'difficultés respiratoires',
            'asthme',
            'dyspnée',
            'respiration']

# %%
new_parif =signal_process(parif_table,event_var='PA04C_PM25',event_threshold =35,duration =12,var_name_list = parif_kw )

# %%
new_parif.head()
# Out:
#                                 PA04C_PM25  PA04C_PM10  PA04C_O3  PA04C_NO2  \
# event_date_index    hour_index
# 2018-02-06 19:00:00 -2                35.0        37.0       6.0       54.0
#                     -1                35.0        37.0       5.0       55.0
#                      0                37.0        38.0       4.0       54.0
#                      1                37.0        39.0       5.0       54.0
#                      2                36.0        39.0       3.0       54.0
#
#                                 PA04C_CO  difficultés respiratoires  asthme  \
# event_date_index    hour_index
# 2018-02-06 19:00:00 -2             500.0                          0      19
#                     -1             500.0                          0      18
#                      0             500.0                          0      15
#                      1             600.0                          0      25
#                      2             600.0                          0      17
#
#                                 dyspnée  respiration
# event_date_index    hour_index
# 2018-02-06 19:00:00 -2                6           27
#                     -1                5           32
#                      0                2           28
#                      1                4           33
#                      2                1           39

# %%
new_parif.to_csv("../output/new_parif.csv")

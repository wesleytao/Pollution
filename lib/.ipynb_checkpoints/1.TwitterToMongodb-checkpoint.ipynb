# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from datetime import datetime
import time
from __future__ import print_function
import json
from pymongo import MongoClient

# %%
# wesley
ckey = 'NdQdQm2OALKTJgtCr9mz8SEAK'
csecret= '2GVLXTHcIy3htHqD5NEIX1IGVuTNjiHMHNEXT2OTTlvjP50hKw'
atoken= '980527124133109766-R2NKGIqJjrUvkOALRw7bdzAHRa4FV18'
asecret= 'r5Px3c5gLtXVuNjJI53qoImV1PW6CeXwRyv8gnjqwTzt0'

# %%
# keran
ckey = 'ok5bMdzCP7UMJMZUMm9tLZdtg'
csecret= 'J9V0m78943Q4dDzQGzOiSpVWex2H1rjSRR5TCAQ2g5zUt7m0Gm'
atoken= '980478205151842304-TQ8AWkaDSh5XtLvsa2hyWfAJONcdHxp'
asecret= 'SbH7zQJnFdQRF6qzUv1BWaUgAjksGdrPdnOGB2Ft8vByl'

# %%
auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

# %%
user=["@BeijingAir"]
original=["air #pollution","空气污染","#airpollution","वायु प्रदुषण","la pollution de l'air","la #pollution","air #pollution","l'air #pollution","वायु प्रदुषण"]
category_1=["forest fire","forest fires"]
category_2=["water poisoning","water contamination"]
category_3=["flood flash","flood water","flood warning"]
category_4=["earthquake"]
category_5=["oil spill","pipeline spill","tarsands spill","tankers spill", "fossilfuel spill","petroleum spill"]
category_6=["acid rain","toxic rain","mildew home","mildew infested","mildew basement","mildew removal","mildew growth","mildew inspection","mold flood","mildew flood"]
category_7=["adelgid","aphid","beetle","earwig","insect","locust","louse","moth","psyllid","termites","termite bites","bugs","bug","bug bites","bugs bites"]

# %%
category_8="""allergy
allergins
pollen
dander
dust
allergy + cough
allergins + cough
pollen + cough
dander + cough
dust + cough
allergy + sneeze
allergins + sneeze
pollen + sneeze
dander + sneeze
dust + sneeze
allergy + asthma
allergins + asthma
pollen + asthma
dander + asthma
dust + asthma
allergy + respiratory
allergins + respiratory
pollen + respiratory
dander + respiratory
dust + respiratory
allergy + lung
allergins + lung
pollen + lung
dander + lung
dust + lung""".split("\n")
category_8=[word.replace("+","") for word in category_8]
category_8=[word.replace("  "," ") for word in category_8]

# %%
# category_17=["@beijingair"]
category_9=["dust"]
category_10=["bed bugs"]

# %%
keywordlist= user +original+category_1+category_2+category_3+category_4+category_5+category_6+category_7+category_8+category_9+category_10
keywordlist
# Out:
# ['@BeijingAir',
#  'air #pollution',
#  '空气污染',
#  '#airpollution',
#  'वायु प्रदुषण',
#  "la pollution de l'air",
#  'la #pollution',
#  'air #pollution',
#  "l'air #pollution",
#  'वायु प्रदुषण',
#  'forest fire',
#  'forest fires',
#  'water poisoning',
#  'water contamination',
#  'flood flash',
#  'flood water',
#  'flood warning',
#  'earthquake',
#  'oil spill',
#  'pipeline spill',
#  'tarsands spill',
#  'tankers spill',
#  'fossilfuel spill',
#  'petroleum spill',
#  'acid rain',
#  'toxic rain',
#  'mildew home',
#  'mildew infested',
#  'mildew basement',
#  'mildew removal',
#  'mildew growth',
#  'mildew inspection',
#  'mold flood',
#  'mildew flood',
#  'adelgid',
#  'aphid',
#  'beetle',
#  'earwig',
#  'insect',
#  'locust',
#  'louse',
#  'moth',
#  'psyllid',
#  'termites',
#  'termite bites',
#  'bugs',
#  'bug',
#  'bug bites',
#  'bugs bites',
#  'allergy',
#  'allergins',
#  'pollen',
#  'dander',
#  'dust',
#  'allergy cough',
#  'allergins cough',
#  'pollen cough',
#  'dander cough',
#  'dust cough',
#  'allergy sneeze',
#  'allergins sneeze',
#  'pollen sneeze',
#  'dander sneeze',
#  'dust sneeze',
#  'allergy asthma',
#  'allergins asthma',
#  'pollen asthma',
#  'dander asthma',
#  'dust asthma',
#  'allergy respiratory',
#  'allergins respiratory',
#  'pollen respiratory',
#  'dander respiratory',
#  'dust respiratory',
#  'allergy lung',
#  'allergins lung',
#  'pollen lung',
#  'dander lung',
#  'dust lung',
#  'dust',
#  'bed bugs']

# %%
# MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
WORDS = keywordlist
client = MongoClient()
# Use twitterdb database. If it doesn't exist, it will be created.
db = client.twitterdb
class StreamListener(tweepy.StreamListener):    
    #This is a class provided by tweepy to access the Twitter Streaming API. 

    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")

    def on_error(self, status_code):
        # On error - if an error occurs, display the error / status code
        print('An Error has occured: ' + repr(status_code))
        return False

    def on_data(self, data):
        #This is the meat of the script...it connects to your mongoDB and stores the tweet
        try:
#                 client = MongoClient(MONGO_HOST)


            # Decode the JSON from Twitter
            datajson = json.loads(data)

            #use tweet id as mongodb id
            datajson["_id"] = datajson.pop("id")

            #grab the 'created_at' data from the Tweet to use for display
            created_at = datajson['created_at']

            #print out a message to the screen that we have collected a tweet
#             print("Tweet collected at " + str(created_at))

            #insert the data into the mongoDB into a collection called twitter_search
            #if twitter_search doesn't exist, it will be created.
            db.twitter_search.insert_one(datajson)
        except Exception as e:
            print(e)

auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
#Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
streamer = tweepy.Stream(auth=auth, listener=listener)
print("Tracking: " + str(WORDS))
streamer.filter(track=WORDS)
# Out:
# Tracking: ['@BeijingAir', 'air #pollution', '空气污染', '#airpollution', 'वायु प्रदुषण', "la pollution de l'air", 'la #pollution', 'air #pollution', "l'air #pollution", 'वायु प्रदुषण', 'forest fire', 'forest fires', 'water poisoning', 'water contamination', 'flood flash', 'flood water', 'flood warning', 'earthquake', 'oil spill', 'pipeline spill', 'tarsands spill', 'tankers spill', 'fossilfuel spill', 'petroleum spill', 'acid rain', 'toxic rain', 'mildew home', 'mildew infested', 'mildew basement', 'mildew removal', 'mildew growth', 'mildew inspection', 'mold flood', 'mildew flood', 'adelgid', 'aphid', 'beetle', 'earwig', 'insect', 'locust', 'louse', 'moth', 'psyllid', 'termites', 'termite bites', 'bugs', 'bug', 'bug bites', 'bugs bites', 'allergy', 'allergins', 'pollen', 'dander', 'dust', 'allergy cough', 'allergins cough', 'pollen cough', 'dander cough', 'dust cough', 'allergy sneeze', 'allergins sneeze', 'pollen sneeze', 'dander sneeze', 'dust sneeze', 'allergy asthma', 'allergins asthma', 'pollen asthma', 'dander asthma', 'dust asthma', 'allergy respiratory', 'allergins respiratory', 'pollen respiratory', 'dander respiratory', 'dust respiratory', 'allergy lung', 'allergins lung', 'pollen lung', 'dander lung', 'dust lung', 'dust', 'bed bugs']
# You are now connected to the streaming API.
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004177063560040449 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004178827776389120 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004195929916825600 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004198699696820224 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004200209239326720 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004207262167003136 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004210785373974529 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004223380143235072 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004227145688707072 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004227893159837696 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004228142876143616 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004232678894284800 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004236954446098432 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004242997171515393 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004243495198945280 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004243500865609728 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004243495198945280 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004247014882750464 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004250046773149698 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004251551530008582 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004254575354789888 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004255077169815553 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004255579106205702 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004255836359745536 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004260868907982849 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004263882620329985 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004267908934094848 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004268414498586624 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1
}
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004668544725016576 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004674849409601542 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004675343079403520 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004676093914374144 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004677859242278912 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004679873502171136 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004685156643303424 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004685406686842880 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004685914688258048 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004689436645314560 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004694725608333312 }
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004699499778863106 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004705045282054144 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004706550462713856 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004706548696961025 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004710321196445696 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004711589960867842 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004714857042571264 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004715610465558528 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004715861196918788 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004721030118756352 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004722151352459266 }
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004726435632705537 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004729197288304642 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004729195946233856 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004730217804414978 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004731476938653696 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004732218550489089 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004735231742676992 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004735993310674945 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004736745680715776 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004736750969868288 }
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004745807088807939 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004745806128263170 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004746556099133440 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004748571537653760 }
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004749080134864903 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004749081359593474 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004750599760408577 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004750859593322496 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004751086421504001 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004755118036697090 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004756386901704704 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004758888418238464 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004760151860137984 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004762416712843264 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004765936702943245 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004766444368773120 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004771475675664385 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004771979814203392 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004771979814203392 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004773994841759744 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004776509410701313 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004777513078276096 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004779282382536705 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004780534042714112 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004785084375785472 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004788086767693825 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004792865200001025 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004796639914192896 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004798649690443776 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004800429069221889 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004801924468760577 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004804444091871232 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004804944652693504 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004804950566662149 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004805204561162240 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004807713707024384 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004807715514793984 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004810729281720320 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004812246663380993 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004814528775798784 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004816789509791745 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004817530156822528 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004819297707757568 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004819791952171008 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004821554184761345 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004822312107966464 }
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004823580482232321 }
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004825833733787649 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004826338941915136 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004826337201147904 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004827093018951680 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004831122549661697 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004831619860090881 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004831875721060353 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004834894223011840 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004835143389974533 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004836146738843649 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004836410069676032 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004836655075905536 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004836912786526209 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004838161543909376 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004838419355357184 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004838665976025088 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004839348376887297 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004839439485448192 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004839672437092352 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004840179448700928 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004841185196863489 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004841704065720320 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004842207604379648 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004844459203280897 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004845968704135168 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004846471546470401 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004846468836966400 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004846722449858562 }
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004850246877351937 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004850493967831040 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004855028560089088 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004859303906275328 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004860306059751424 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004860812656340999 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004861067611156481 }
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004864357912625153 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004865095829090305 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004868364878188551 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004868364878188551 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004868364257202176 }
# 'id'
# 'id'
# 'id'
# 'id'
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004874401827999744 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004876417560121344 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004876671386697728 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004879686348857344 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004881450506772480 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004883229638254592 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004887250235154432 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004891515368292353 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004892520059465728 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004892520059465728 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004892542159056896 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004893778577010688 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004895041377193984 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004896299177652231 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004896556992958469 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004901084232642562 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004903848102670336 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004907874626048000 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004909638221828097 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004910392177459201 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004922976519634944 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004929267648454657 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004931031978381312 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004932285240508417 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004937822841724929 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004939331939659776 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004939584977825793 }
# E11000 duplicate key error collection: twitterdb.twitter_search index: _id_ dup key: { : 1004942098460635136 }
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1520         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1521             raise WantReadError()
#    1522         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     293             if not rd:
# --> 294                 raise timeout('The read operation timed out')
#     295             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# <ipython-input-23-f2c6ee31a496> in <module>()
#      47 streamer = tweepy.Stream(auth=auth, listener=listener)
#      48 print("Tracking: " + str(WORDS))
# ---> 49 streamer.filter(track=WORDS)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     295             # call a handler first so that the exception can be logged.
#     296             self.listener.on_exception(exc_info[1])
# --> 297             six.reraise(*exc_info)
#     298
#     299     def _data(self, data):
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     399                         # raised during streaming, so all calls with incorrect
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#     403         if data:
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     305                 # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     306                 # there is yet no clean way to get at it from this context.
# --> 307                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     308
#     309             except BaseSSLError as e:
#
# ReadTimeoutError: HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.

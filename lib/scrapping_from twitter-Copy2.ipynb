# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from datetime import datetime
import time

from __future__ import print_function
import json
from pymongo import MongoClient

# %%
help(tweepy.api)
# Out:
# Help on API in module tweepy.api object:
#
# class API(builtins.object)
#  |  Twitter API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |      Api instance Constructor
#  |
#  |      :param auth_handler:
#  |      :param host:  url of the server of the rest api, default:'api.twitter.com'
#  |      :param search_host: url of the search server, default:'search.twitter.com'
#  |      :param upload_host: url of the upload server, default:'upload.twitter.com'
#  |      :param cache: Cache to query if a GET method is used, default:None
#  |      :param api_root: suffix of the api version, default:'/1.1'
#  |      :param search_root: suffix of the search version, default:''
#  |      :param upload_root: suffix of the upload version, default:'/1.1'
#  |      :param retry_count: number of allowed retries, default:0
#  |      :param retry_delay: delay in second between retries, default:0
#  |      :param retry_errors: default:None
#  |      :param timeout: delay before to consider the request as timed out in seconds, default:60
#  |      :param parser: ModelParser instance to parse the responses, default:None
#  |      :param compression: If the response is compressed, default:False
#  |      :param wait_on_rate_limit: If the api wait when it hits the rate limit, default:False
#  |      :param wait_on_rate_limit_notify: If the api print a notification when the rate limit is hit, default:False
#  |      :param proxy: Url to use as proxy during the HTTP request, default:''
#  |
#  |      :raise TypeError: If the given parser is not a ModelParser instance.
#  |
#  |  add_list_members(self, screen_name=None, user_id=None, slug=None, list_id=None, owner_id=None, owner_screen_name=None)
#  |      Perform bulk add of list members from user ID or screenname
#  |
#  |  lookup_friendships(self, user_ids=None, screen_names=None)
#  |      Perform bulk look up of friendships from user ID or screenname
#  |
#  |  lookup_users(self, user_ids=None, screen_names=None, include_entities=None)
#  |      Perform bulk look up of users from user ID or screenname
#  |
#  |  me(self)
#  |      Get the authenticated user
#  |
#  |  media_upload(self, filename, *args, **kwargs)
#  |      :reference: https://dev.twitter.com/rest/reference/post/media/upload
#  |      :allowed_param:
#  |
#  |  remove_list_members(self, screen_name=None, user_id=None, slug=None, list_id=None, owner_id=None, owner_screen_name=None)
#  |      Perform bulk remove of list members from user ID or screenname
#  |
#  |  statuses_lookup(self, id_, include_entities=None, trim_user=None, map_=None)
#  |
#  |  update_profile_background_image(self, filename, **kargs)
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/update_profile_background_image
#  |      :allowed_param:'tile', 'include_entities', 'skip_status', 'use'
#  |
#  |  update_profile_banner(self, filename, **kargs)
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/update_profile_banner
#  |      :allowed_param:'width', 'height', 'offset_left', 'offset_right'
#  |
#  |  update_profile_image(self, filename, file_=None)
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/update_profile_image
#  |      :allowed_param:'include_entities', 'skip_status'
#  |
#  |  update_status(self, *args, **kwargs)
#  |      :reference: https://dev.twitter.com/rest/reference/post/statuses/update
#  |      :allowed_param:'status', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'auto_populate_reply_metadata', 'lat', 'long', 'source', 'place_id', 'display_coordinates', 'media_ids'
#  |
#  |  update_with_media(self, filename, *args, **kwargs)
#  |      :reference: https://dev.twitter.com/rest/reference/post/statuses/update_with_media
#  |      :allowed_param:'status', 'possibly_sensitive', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'auto_populate_reply_metadata', 'lat', 'long', 'place_id', 'display_coordinates'
#  |
#  |  verify_credentials(self, **kargs)
#  |      :reference: https://dev.twitter.com/rest/reference/get/account/verify_credentials
#  |      :allowed_param:'include_entities', 'skip_status', 'include_email'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  add_list_member
#  |      :reference: https://dev.twitter.com/docs/api/1.1/post/lists/members/create
#  |      :allowed_param:'screen_name', 'user_id', 'owner_screen_name',
#  |       'owner_id', 'slug', 'list_id'
#  |
#  |  blocks
#  |      :reference: https://dev.twitter.com/rest/reference/get/blocks/list
#  |      :allowed_param:'cursor'
#  |
#  |  blocks_ids
#  |      :reference: https://dev.twitter.com/rest/reference/get/blocks/ids
#  |
#  |  configuration
#  |      :reference: https://dev.twitter.com/rest/reference/get/help/configuration
#  |
#  |  create_block
#  |      :reference: https://dev.twitter.com/rest/reference/post/blocks/create
#  |      :allowed_param:'id', 'user_id', 'screen_name'
#  |
#  |  create_favorite
#  |      :reference:https://dev.twitter.com/rest/reference/post/favorites/create
#  |      :allowed_param:'id'
#  |
#  |  create_friendship
#  |      :reference: https://dev.twitter.com/rest/reference/post/friendships/create
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'follow'
#  |
#  |  create_list
#  |      :reference: https://dev.twitter.com/rest/reference/post/lists/create
#  |      :allowed_param:'name', 'mode', 'description'
#  |
#  |  create_saved_search
#  |      :reference: https://dev.twitter.com/rest/reference/post/saved_searches/create
#  |      :allowed_param:'query'
#  |
#  |  destroy_block
#  |      :reference: https://dev.twitter.com/rest/reference/post/blocks/destroy
#  |      :allowed_param:'id', 'user_id', 'screen_name'
#  |
#  |  destroy_direct_message
#  |      :reference: https://dev.twitter.com/rest/reference/post/direct_messages/destroy
#  |      :allowed_param:'id'
#  |
#  |  destroy_favorite
#  |      :reference: https://dev.twitter.com/rest/reference/post/favorites/destroy
#  |      :allowed_param:'id'
#  |
#  |  destroy_friendship
#  |      :reference: https://dev.twitter.com/rest/reference/post/friendships/destroy
#  |      :allowed_param:'id', 'user_id', 'screen_name'
#  |
#  |  destroy_list
#  |      :reference: https://dev.twitter.com/rest/reference/post/lists/destroy
#  |      :allowed_param:'owner_screen_name', 'owner_id', 'list_id', 'slug'
#  |
#  |  destroy_saved_search
#  |      :reference: https://dev.twitter.com/rest/reference/post/saved_searches/destroy/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  destroy_status
#  |      :reference: https://dev.twitter.com/rest/reference/post/statuses/destroy/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  direct_messages
#  |      :reference: https://dev.twitter.com/rest/reference/get/direct_messages
#  |      :allowed_param:'since_id', 'max_id', 'count', 'full_text'
#  |
#  |  favorites
#  |      :reference: https://dev.twitter.com/rest/reference/get/favorites/list
#  |      :allowed_param:'screen_name', 'user_id', 'max_id', 'count', 'since_id', 'max_id'
#  |
#  |  followers
#  |      :reference: https://dev.twitter.com/rest/reference/get/followers/list
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'cursor', 'count', 'skip_status', 'include_user_entities'
#  |
#  |  followers_ids
#  |      :reference: https://dev.twitter.com/rest/reference/get/followers/ids
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'cursor', 'count'
#  |
#  |  friends
#  |      :reference: https://dev.twitter.com/rest/reference/get/friends/list
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'cursor', 'skip_status', 'include_user_entities'
#  |
#  |  friends_ids
#  |      :reference: https://dev.twitter.com/rest/reference/get/friends/ids
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'cursor'
#  |
#  |  friendships_incoming
#  |      :reference: https://dev.twitter.com/rest/reference/get/friendships/incoming
#  |      :allowed_param:'cursor'
#  |
#  |  friendships_outgoing
#  |      :reference: https://dev.twitter.com/rest/reference/get/friendships/outgoing
#  |      :allowed_param:'cursor'
#  |
#  |  geo_id
#  |      :reference: https://dev.twitter.com/rest/reference/get/geo/id/%3Aplace_id
#  |      :allowed_param:'id'
#  |
#  |  geo_search
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/geo/search
#  |      :allowed_param:'lat', 'long', 'query', 'ip', 'granularity',
#  |       'accuracy', 'max_results', 'contained_within
#  |
#  |  geo_similar_places
#  |      :reference: https://dev.twitter.com/rest/reference/get/geo/similar_places
#  |      :allowed_param:'lat', 'long', 'name', 'contained_within'
#  |
#  |  get_direct_message
#  |      :reference: https://dev.twitter.com/rest/reference/get/direct_messages/show
#  |      :allowed_param:'id', 'full_text'
#  |
#  |  get_list
#  |      :reference: https://dev.twitter.com/rest/reference/get/lists/show
#  |      :allowed_param:'owner_screen_name', 'owner_id', 'slug', 'list_id'
#  |
#  |  get_oembed
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/oembed
#  |      :allowed_param:'id', 'url', 'maxwidth', 'hide_media', 'omit_script', 'align', 'related', 'lang'
#  |
#  |  get_saved_search
#  |      :reference: https://dev.twitter.com/rest/reference/get/saved_searches/show/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  get_settings
#  |      :reference: https://dev.twitter.com/rest/reference/get/account/settings
#  |
#  |  get_status
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/show/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  get_user
#  |      :reference: https://dev.twitter.com/rest/reference/get/users/show
#  |      :allowed_param:'id', 'user_id', 'screen_name'
#  |
#  |  home_timeline
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/home_timeline
#  |      :allowed_param:'since_id', 'max_id', 'count'
#  |
#  |  list_members
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/lists/members
#  |      :allowed_param:'owner_screen_name', 'slug', 'list_id',
#  |       'owner_id', 'cursor
#  |
#  |  list_subscribers
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/lists/subscribers
#  |      :allowed_param:'owner_screen_name', 'slug', 'owner_id',
#  |       'list_id', 'cursor
#  |
#  |  list_timeline
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/lists/statuses
#  |      :allowed_param:'owner_screen_name', 'slug', 'owner_id', 'list_id',
#  |       'since_id', 'max_id', 'count', 'include_rts
#  |
#  |  lists_all
#  |      :reference: https://dev.twitter.com/rest/reference/get/lists/list
#  |      :allowed_param:'screen_name', 'user_id'
#  |
#  |  lists_memberships
#  |      :reference: https://dev.twitter.com/rest/reference/get/lists/memberships
#  |      :allowed_param:'screen_name', 'user_id', 'filter_to_owned_lists', 'cursor'
#  |
#  |  lists_subscriptions
#  |      :reference: https://dev.twitter.com/rest/reference/get/lists/subscriptions
#  |      :allowed_param:'screen_name', 'user_id', 'cursor'
#  |
#  |  mentions_timeline
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/mentions_timeline
#  |      :allowed_param:'since_id', 'max_id', 'count'
#  |
#  |  rate_limit_status
#  |      :reference: https://dev.twitter.com/rest/reference/get/application/rate_limit_status
#  |      :allowed_param:'resources'
#  |
#  |  related_results
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/related_results/show/%3id.format
#  |      :allowed_param:'id'
#  |
#  |  remove_list_member
#  |      :reference: https://dev.twitter.com/docs/api/1.1/post/lists/members/destroy
#  |      :allowed_param:'screen_name', 'user_id', 'owner_screen_name',
#  |       'owner_id', 'slug', 'list_id'
#  |
#  |  report_spam
#  |      :reference: https://dev.twitter.com/rest/reference/post/users/report_spam
#  |      :allowed_param:'user_id', 'screen_name'
#  |
#  |  retweet
#  |      :reference: https://dev.twitter.com/rest/reference/post/statuses/retweet/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  retweeters
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/retweeters/ids
#  |      :allowed_param:'id', 'cursor', 'stringify_ids
#  |
#  |  retweets
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/retweets/%3Aid
#  |      :allowed_param:'id', 'count'
#  |
#  |  retweets_of_me
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/retweets_of_me
#  |      :allowed_param:'since_id', 'max_id', 'count'
#  |
#  |  reverse_geocode
#  |      :reference: https://dev.twitter.com/rest/reference/get/geo/reverse_geocode
#  |      :allowed_param:'lat', 'long', 'accuracy', 'granularity', 'max_results'
#  |
#  |  saved_searches
#  |      :reference: https://dev.twitter.com/rest/reference/get/saved_searches/show/%3Aid
#  |
#  |  search
#  |      :reference: https://dev.twitter.com/rest/reference/get/search/tweets
#  |      :allowed_param:'q', 'lang', 'locale', 'since_id', 'geocode',
#  |       'max_id', 'since', 'until', 'result_type', 'count',
#  |        'include_entities', 'from', 'to', 'source'
#  |
#  |  search_users
#  |      :reference: https://dev.twitter.com/rest/reference/get/users/search
#  |      :allowed_param:'q', 'count', 'page'
#  |
#  |  send_direct_message
#  |      :reference: https://dev.twitter.com/rest/reference/post/direct_messages/new
#  |      :allowed_param:'user', 'screen_name', 'user_id', 'text'
#  |
#  |  sent_direct_messages
#  |      :reference: https://dev.twitter.com/rest/reference/get/direct_messages/sent
#  |      :allowed_param:'since_id', 'max_id', 'count', 'page', 'full_text'
#  |
#  |  set_delivery_device
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/update_delivery_device
#  |      :allowed_param:'device'
#  |
#  |  set_settings
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/settings
#  |      :allowed_param:'sleep_time_enabled', 'start_sleep_time',
#  |      'end_sleep_time', 'time_zone', 'trend_location_woeid',
#  |      'allow_contributor_request', 'lang'
#  |
#  |  show_friendship
#  |      :reference: https://dev.twitter.com/rest/reference/get/friendships/show
#  |      :allowed_param:'source_id', 'source_screen_name', 'target_id', 'target_screen_name'
#  |
#  |  show_list_member
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/lists/members/show
#  |      :allowed_param:'list_id', 'slug', 'user_id', 'screen_name',
#  |       'owner_screen_name', 'owner_id
#  |
#  |  show_list_subscriber
#  |      :reference: https://dev.twitter.com/docs/api/1.1/get/lists/subscribers/show
#  |      :allowed_param:'owner_screen_name', 'slug', 'screen_name',
#  |       'owner_id', 'list_id', 'user_id
#  |
#  |  subscribe_list
#  |      :reference: https://dev.twitter.com/docs/api/1.1/post/lists/subscribers/create
#  |      :allowed_param:'owner_screen_name', 'slug', 'owner_id',
#  |      'list_id'
#  |
#  |  suggested_categories
#  |      :reference: https://dev.twitter.com/rest/reference/get/users/suggestions
#  |      :allowed_param:'lang'
#  |
#  |  suggested_users
#  |      :reference: https://dev.twitter.com/rest/reference/get/users/suggestions/%3Aslug
#  |      :allowed_param:'slug', 'lang'
#  |
#  |  suggested_users_tweets
#  |      :reference: https://dev.twitter.com/rest/reference/get/users/suggestions/%3Aslug/members
#  |      :allowed_param:'slug'
#  |
#  |  supported_languages
#  |      :reference: https://dev.twitter.com/rest/reference/get/help/languages
#  |
#  |  trends_available
#  |      :reference: https://dev.twitter.com/rest/reference/get/trends/available
#  |
#  |  trends_closest
#  |      :reference: https://dev.twitter.com/rest/reference/get/trends/closest
#  |      :allowed_param:'lat', 'long'
#  |
#  |  trends_place
#  |      :reference: https://dev.twitter.com/rest/reference/get/trends/place
#  |      :allowed_param:'id', 'exclude'
#  |
#  |  unretweet
#  |      :reference: https://dev.twitter.com/rest/reference/post/statuses/unretweet/%3Aid
#  |      :allowed_param:'id'
#  |
#  |  unsubscribe_list
#  |      :reference: https://dev.twitter.com/docs/api/1.1/post/lists/subscribers/destroy
#  |      :allowed_param:'owner_screen_name', 'slug', 'owner_id',
#  |      'list_id'
#  |
#  |  update_list
#  |      :reference: https://dev.twitter.com/rest/reference/post/lists/update
#  |      :allowed_param: list_id', 'slug', 'name', 'mode', 'description', 'owner_screen_name', 'owner_id'
#  |
#  |  update_profile
#  |      :reference: https://dev.twitter.com/rest/reference/post/account/update_profile
#  |      :allowed_param:'name', 'url', 'location', 'description', 'profile_link_color'
#  |
#  |  user_timeline
#  |      :reference: https://dev.twitter.com/rest/reference/get/statuses/user_timeline
#  |      :allowed_param:'id', 'user_id', 'screen_name', 'since_id', 'max_id', 'count', 'include_rts'

# %%
api= tweepy.API(auth)

# %%
api.home_timeline()
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Mon May 21 16:44:25 +0000 2018', 'id': 998605445186179077, 'id_str': '998605445186179077', 'text': 'If you use Sign in with Twitter, remember to whitelist your callback URLs before the June 12th deadline. See the fo… https://t.co/iQZ0HulDJU', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/iQZ0HulDJU', 'expanded_url': 'https://twitter.com/i/web/status/998605445186179077', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': 998605443021856768, 'in_reply_to_status_id_str': '998605443021856768', 'in_reply_to_user_id': 6253282, 'in_reply_to_user_id_str': '6253282', 'in_reply_to_screen_name': 'TwitterAPI', 'user': {'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.", 'url': 'https://t.co/8IkCzCDr19', 'entities': {'url': {'urls': [{'url': 'https://t.co/8IkCzCDr19', 'expanded_url': 'https://developer.twitter.com', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 6282224, 'friends_count': 12, 'listed_count': 13002, 'created_at': 'Wed May 23 06:01:13 +0000 2007', 'favourites_count': 29, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 3628, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6253282/1497491515', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 27, 'favorite_count': 44, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 21, 16, 44, 25), id=998605445186179077, id_str='998605445186179077', text='If you use Sign in with Twitter, remember to whitelist your callback URLs before the June 12th deadline. See the fo… https://t.co/iQZ0HulDJU', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/iQZ0HulDJU', 'expanded_url': 'https://twitter.com/i/web/status/998605445186179077', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=998605443021856768, in_reply_to_status_id_str='998605443021856768', in_reply_to_user_id=6253282, in_reply_to_user_id_str='6253282', in_reply_to_screen_name='TwitterAPI', author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, servi ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Mon May 21 16:44:25 +0000 2018', 'id': 998605443021856768, 'id_str': '998605443021856768', 'text': 'Reminder‼️ We are rolling out a few changes to the developer platform in advance of new European Union regulations… https://t.co/2F4zSjdN6Q', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2F4zSjdN6Q', 'expanded_url': 'https://twitter.com/i/web/status/998605443021856768', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [116, 139]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.", 'url': 'https://t.co/8IkCzCDr19', 'entities': {'url': {'urls': [{'url': 'https://t.co/8IkCzCDr19', 'expanded_url': 'https://developer.twitter.com', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 6282224, 'friends_count': 12, 'listed_count': 13002, 'created_at': 'Wed May 23 06:01:13 +0000 2007', 'favourites_count': 29, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 3628, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6253282/1497491515', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 37, 'favorite_count': 55, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 21, 16, 44, 25), id=998605443021856768, id_str='998605443021856768', text='Reminder‼️ We are rolling out a few changes to the developer platform in advance of new European Union regulations… https://t.co/2F4zSjdN6Q', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2F4zSjdN6Q', 'expanded_url': 'https://twitter.com/i/web/status/998605443021856768', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [116, 139]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.", 'url': 'https ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Mon May 21 14:03:42 +0000 2018', 'id': 998564997092560896, 'id_str': '998564997092560896', 'text': 'The #TapIntoTwitter Delhi meetup is happening on May 26th! https://t.co/lrtdqQfsp1', 'truncated': False, 'entities': {'hashtags': [{'text': 'TapIntoTwitter', 'indices': [4, 19]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/lrtdqQfsp1', 'expanded_url': 'https://twitter.com/lvhcolorado/status/997679106790645760', 'display_url': 'twitter.com/lvhcolorado/st…', 'indices': [59, 82]}]}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 997679106790645760, 'quoted_status_id_str': '997679106790645760', 'quoted_status': {'created_at': 'Sat May 19 03:23:29 +0000 2018', 'id': 997679106790645760, 'id_str': '997679106790645760', 'text': 'Upcoming TapIntoTwitter meetup in Delhi on May 26th, some seats available sign up today!\nhttps://t.co/3YCdDMfQzC', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/3YCdDMfQzC', 'expanded_url': 'http://meetu.ps/e/Fhrkw/tMVZq/a', 'display_url': 'meetu.ps/e/Fhrkw/tMVZq/a', 'indices': [89, 112]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 97370635, 'id_str': '97370635', 'name': 'laura harrison', 'screen_name': 'lvhcolorado', 'location': 'Colorado, USA', 'description': 'Developer Evangelist, Community Manager and Brand Ambassador.', 'url': None, 'entities': {'descr ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Fri May 18 15:48:35 +0000 2018', 'id': 997504226656899073, 'id_str': '997504226656899073', 'text': 'The Account Activity API is the best way to get events to respond to. Our REST API endpoints also provide the solut… https://t.co/ZHtPOdsmE9', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ZHtPOdsmE9', 'expanded_url': 'https://twitter.com/i/web/status/997504226656899073', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 10, 'favorite_count': 33, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 18, 15, 48, 35), id=997504226656899073, id_str='997504226656899073', text='The Account Activity API is the best way to get events to respond to. Our REST API endpoints also provide the solut… https://t.co/ZHtPOdsmE9', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ZHtPOdsmE9', 'expanded_url': 'https://twitter.com/i/web/status/997504226656899073', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Media Studio', source_url='https://studio.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descrip ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Fri May 18 15:47:23 +0000 2018', 'id': 997503927523295234, 'id_str': '997503927523295234', 'text': 'The Account Activity API is the best way to get events to respond to. Our REST API endpoints are the solution to cr… https://t.co/Solh97zSVG', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Solh97zSVG', 'expanded_url': 'https://twitter.com/i/web/status/997503927523295234', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 10, 'favorite_count': 17, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 18, 15, 47, 23), id=997503927523295234, id_str='997503927523295234', text='The Account Activity API is the best way to get events to respond to. Our REST API endpoints are the solution to cr… https://t.co/Solh97zSVG', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Solh97zSVG', 'expanded_url': 'https://twitter.com/i/web/status/997503927523295234', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Media Studio', source_url='https://studio.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descrip ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:32:50 +0000 2018', 'id': 996790589667475456, 'id_str': '996790589667475456', 'text': 'Once connected the Account Activity API delivers data for the account that owns the Twitter app, or for other accou… https://t.co/N8xgN9CNFA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/N8xgN9CNFA', 'expanded_url': 'https://twitter.com/i/web/status/996790589667475456', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 12, 'favorite_count': 28, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 32, 50), id=996790589667475456, id_str='996790589667475456', text='Once connected the Account Activity API delivers data for the account that owns the Twitter app, or for other accou… https://t.co/N8xgN9CNFA', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/N8xgN9CNFA', 'expanded_url': 'https://twitter.com/i/web/status/996790589667475456', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Media Studio', source_url='https://studio.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descrip ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:32:39 +0000 2018', 'id': 996790540908707840, 'id_str': '996790540908707840', 'text': 'The Account Activity API is a webhooks based service. To get started developers will need to establish their webhoo… https://t.co/j33jzEmohr', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j33jzEmohr', 'expanded_url': 'https://twitter.com/i/web/status/996790540908707840', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 9, 'favorite_count': 25, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 32, 39), id=996790540908707840, id_str='996790540908707840', text='The Account Activity API is a webhooks based service. To get started developers will need to establish their webhoo… https://t.co/j33jzEmohr', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/j33jzEmohr', 'expanded_url': 'https://twitter.com/i/web/status/996790540908707840', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Media Studio', source_url='https://studio.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descript ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:32:26 +0000 2018', 'id': 996790489910202369, 'id_str': '996790489910202369', 'text': 'The Account Activity API enables developers to build customer service, engagement, and chatbots, among other uses t… https://t.co/ucOUG4SxGc', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ucOUG4SxGc', 'expanded_url': 'https://twitter.com/i/web/status/996790489910202369', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 13, 'favorite_count': 39, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 32, 26), id=996790489910202369, id_str='996790489910202369', text='The Account Activity API enables developers to build customer service, engagement, and chatbots, among other uses t… https://t.co/ucOUG4SxGc', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ucOUG4SxGc', 'expanded_url': 'https://twitter.com/i/web/status/996790489910202369', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Media Studio', source_url='https://studio.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descrip ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:32:16 +0000 2018', 'id': 996790447048613888, 'id_str': '996790447048613888', 'text': 'Today we announced the Account Activity API is generally available as a premium and enterprise API. 🔔 https://t.co/xnlF9kPevi', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 996424614342361089, 'id_str': '996424614342361089', 'indices': [102, 125], 'media_url': 'http://pbs.twimg.com/media/DdQFTGjVAAAXqva.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DdQFTGjVAAAXqva.jpg', 'url': 'https://t.co/xnlF9kPevi', 'display_url': 'pic.twitter.com/xnlF9kPevi', 'expanded_url': 'https://twitter.com/TwitterDev/status/996790447048613888/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 996424614342361089, 'id_str': '996424614342361089', 'indices': [102, 125], 'media_url': 'http://pbs.twimg.com/media/DdQFTGjVAAAXqva.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DdQFTGjVAAAXqva.jpg', 'url': 'https://t.co/xnlF9kPevi', 'display_url': 'pic.twitter.com/xnlF9kPevi', 'expanded_url': 'https://twitter.com/TwitterDev/status/996790447048613888/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1600, 'h': 900, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 127928, 'variants': [{'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/996424614342361089/vid/1280x720/DPyHoxFEELnlVxhQ.mp4?tag=2'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/996424614342361089/vid/640x360/IwvWSNatYYJ5ORup.mp4?tag=2'}, {'bitrate': 320000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/996424614342361089/vid/320x180/m-0Fer5aCzUkC1gj.mp4?tag=2'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/996424614342361089/pl/LjBilFmy4XFTJyhz.m3u8?tag=2'}]}, 'additional_media_info': {'title': '', 'description': '', 'embeddable': True, 'monetizable': False}}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:02:41 +0000 2018', 'id': 996783003018854403, 'id_str': '996783003018854403', 'text': 'If you have additional questions on our APIs or would like some help as you make changes, our team and expert commu… https://t.co/gjSjuBYtna', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gjSjuBYtna', 'expanded_url': 'https://twitter.com/i/web/status/996783003018854403', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': 996783001890586627, 'in_reply_to_status_id_str': '996783001890586627', 'in_reply_to_user_id': 2244994945, 'in_reply_to_user_id_str': '2244994945', 'in_reply_to_screen_name': 'TwitterDev', 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 21, 'favorite_count': 27, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 2, 41), id=996783003018854403, id_str='996783003018854403', text='If you have additional questions on our APIs or would like some help as you make changes, our team and expert commu… https://t.co/gjSjuBYtna', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gjSjuBYtna', 'expanded_url': 'https://twitter.com/i/web/status/996783003018854403', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=996783001890586627, in_reply_to_status_id_str='996783001890586627', in_reply_to_user_id=2244994945, in_reply_to_user_id_str='2244994945', in_reply_to_screen_name='TwitterDev', author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:02:41 +0000 2018', 'id': 996783001890586627, 'id_str': '996783001890586627', 'text': 'We have resources that detail the changes that are being made. These resources describe the best way to keep your s… https://t.co/RWHjDODCOC', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RWHjDODCOC', 'expanded_url': 'https://twitter.com/i/web/status/996783001890586627', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': 996783000741384192, 'in_reply_to_status_id_str': '996783000741384192', 'in_reply_to_user_id': 2244994945, 'in_reply_to_user_id_str': '2244994945', 'in_reply_to_screen_name': 'TwitterDev', 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 15, 'favorite_count': 24, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 2, 41), id=996783001890586627, id_str='996783001890586627', text='We have resources that detail the changes that are being made. These resources describe the best way to keep your s… https://t.co/RWHjDODCOC', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RWHjDODCOC', 'expanded_url': 'https://twitter.com/i/web/status/996783001890586627', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=996783000741384192, in_reply_to_status_id_str='996783000741384192', in_reply_to_user_id=2244994945, in_reply_to_user_id_str='2244994945', in_reply_to_screen_name='TwitterDev', author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': ...
# ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Wed May 16 16:02:39 +0000 2018', 'id': 996782993200025600, 'id_str': '996782993200025600', 'text': 'Today we’re excited to announce the general availability of Account Activity API. Now developers can get started fo… https://t.co/La1dPEoQON', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/La1dPEoQON', 'expanded_url': 'https://twitter.com/i/web/status/996782993200025600', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 232, 'favorite_count': 460, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 16, 16, 2, 39), id=996782993200025600, id_str='996782993200025600', text='Today we’re excited to announce the general availability of Account Activity API. Now developers can get started fo… https://t.co/La1dPEoQON', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/La1dPEoQON', 'expanded_url': 'https://twitter.com/i/web/status/996782993200025600', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'descriptio ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Thu May 10 18:51:39 +0000 2018', 'id': 994651195556823040, 'id_str': '994651195556823040', 'text': 'Do you parse Quote Tweet URLs as part of your Twitter integration? \n\nWe’re updating the way that URLs are rendered… https://t.co/LEQmHGzjor', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/LEQmHGzjor', 'expanded_url': 'https://twitter.com/i/web/status/994651195556823040', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [116, 139]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.", 'url': 'https://t.co/8IkCzCDr19', 'entities': {'url': {'urls': [{'url': 'https://t.co/8IkCzCDr19', 'expanded_url': 'https://developer.twitter.com', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 6282224, 'friends_count': 12, 'listed_count': 13002, 'created_at': 'Wed May 23 06:01:13 +0000 2007', 'favourites_count': 29, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': True, 'statuses_count': 3628, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942858479592554497/BbazLO9L_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6253282/1497491515', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 40, 'favorite_count': 76, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 5, 10, 18, 51, 39), id=994651195556823040, id_str='994651195556823040', text='Do you parse Quote Tweet URLs as part of your Twitter integration? \n\nWe’re updating the way that URLs are rendered… https://t.co/LEQmHGzjor', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/LEQmHGzjor', 'expanded_url': 'https://twitter.com/i/web/status/994651195556823040', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [116, 139]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 6253282, 'id_str': '6253282', 'name': 'Twitter API', 'screen_name': 'TwitterAPI', 'location': 'San Francisco, CA', 'description': "The Real Twitter API. Tweets about API changes, service issues and our Developer Platform. Don't get an answer? It's on my website.", 'url': 'h ...
#  Status(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'created_at': 'Mon Apr 30 16:39:29 +0000 2018', 'id': 990994054442770432, 'id_str': '990994054442770432', 'text': 'Heads up! We are discontinuing support for the Twitter Kit SDK on October 31, 2018. Read more here 👇 https://t.co/kgDJnVlLT7', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kgDJnVlLT7', 'expanded_url': 'https://blog.twitter.com/developer/en_us/topics/tools/2018/discontinuing-support-for-twitter-kit-sdk.html', 'display_url': 'blog.twitter.com/developer/en_u…', 'indices': [101, 124]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2244994945, 'id_str': '2244994945', 'name': 'Twitter Dev', 'screen_name': 'TwitterDev', 'location': 'Internet', 'description': 'Your official source for Twitter Platform news, updates & events. Need technical help? Visit https://t.co/mGHnxZU8c1 ⌨️ #TapIntoTwitter', 'url': 'https://t.co/FGl7VOULyL', 'entities': {'url': {'urls': [{'url': 'https://t.co/FGl7VOULyL', 'expanded_url': 'https://developer.twitter.com/', 'display_url': 'developer.twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/mGHnxZU8c1', 'expanded_url': 'https://twittercommunity.com/', 'display_url': 'twittercommunity.com', 'indices': [93, 116]}]}}, 'protected': False, 'followers_count': 498833, 'friends_count': 1485, 'listed_count': 1368, 'created_at': 'Sat Dec 14 04:35:55 +0000 2013', 'favourites_count': 2207, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 3352, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880136122604507136/xHrnqf1T_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244994945/1498675817', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 46, 'favorite_count': 60, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 4, 30, 16, 39, 29), id=990994054442770432, id_str='990994054442770432', text='Heads up! We are discontinuing support for the Twitter Kit SDK on October 31, 2018. Read more here 👇 https://t.co/kgDJnVlLT7', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kgDJnVlLT7', 'expanded_url': 'https://blog.twitter.com/developer/en_us/topics/tools/2018/discontinuing-support-for-twitter-kit-sdk.html', 'display_url': 'blog.twitter.com/developer/en_u…', 'indices': [101, 124]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f24c72cebe0>, _json={'id': 2244994945, 'id_str': '2244994945',  ...

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '980527124133109766-R2NKGIqJjrUvkOALRw7bdzAHRa4FV18'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 74,
#     'reset': 1527042618}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1527042771},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1527042771},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1527042771},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1527042771}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1527042771},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1527042771},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1527042771},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1527042771},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1527042771},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1527042771}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1527042771},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1527042771}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1527042771}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1527042771},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1527042771},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1527042771},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1527042771},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1527042771},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1527042771}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1527042771},
#    '/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1527042771}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771}},
#   'safety': {'/safety/detection_feedback': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1527042771}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1527042771}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 14,
#     'reset': 1527042359},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1527042771},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1527042771},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 899, 'reset': 1527042503},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1527042771}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1527042771},
#    '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1527042771},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1527042771}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771}},
#   'tweets': {'/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1527042771},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1527042771}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1527042771},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1527042771},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1527042771},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1527042771},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1527042771},
#    '/users/show/:id': {'limit': 900, 'remaining': 899, 'reset': 1527042618},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1527042771},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1527042771}}}}

# %%
# wesley
ckey = 'NdQdQm2OALKTJgtCr9mz8SEAK'
csecret= '2GVLXTHcIy3htHqD5NEIX1IGVuTNjiHMHNEXT2OTTlvjP50hKw'
atoken= '980527124133109766-R2NKGIqJjrUvkOALRw7bdzAHRa4FV18'
asecret= 'r5Px3c5gLtXVuNjJI53qoImV1PW6CeXwRyv8gnjqwTzt0'

# %%
# 
ckey="m5kFFDfq3b9oh0wKwiteAgd7J"
csecret="tQ2pH1oqhSoy4QQCN25xGZBQ1dMuMtmMUtlSZb9pzO2nNf1S9s"
akey="986390268889923584-u9gAJwMsyZm0fwMeTdU3JgXzsEOWJSm"
asecret="0ZOtMyC4gku2s9LMNx04dsybSaVpnNvQg7lZJh4iuuMCP"

# %%
auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

# %%
path="../data"
filepath=path+"/"+"alltogether-"+datetime.now().strftime('%Y-%m-%d-%H-%M')+".json"
filepath
# Out:
# '../data/alltogether-2018-05-22-21-36.json'

# %%
original=["air #pollution"]
category_1=["forest fire","forest fires"]
category_2=["water poisoning","water contamination"]
category_3=["flood flash","flood water","flood warning"]
category_4=["earthquake"]
category_5=["oil spill","pipeline spill","tarsands spill","tankers spill", "fossilfuel spill","petroleum spill"]
category_6=["acid rain","toxic rain","mildew home","mildew infested","mildew basement","mildew removal","mildew growth","mildew inspection","mold flood","mildew flood"]
category_15=["adelgid","aphid","beetle","earwig","insect","locust","louse","moth","psyllid","termites","termite","bites","bugs","bug","bug bites","bugs bites"]

# %%
category_16="""allergy
allergins
pollen
dander
dust
allergy + cough
allergins + cough
pollen + cough
dander + cough
dust + cough
allergy + sneeze
allergins + sneeze
pollen + sneeze
dander + sneeze
dust + sneeze
allergy + asthma
allergins + asthma
pollen + asthma
dander + asthma
dust + asthma
allergy + respiratory
allergins + respiratory
pollen + respiratory
dander + respiratory
dust + respiratory
allergy + lung
allergins + lung
pollen + lung
dander + lung
dust + lung""".split("\n")
category_16=[word.replace("+","") for word in category_16]

# %%
category_17=["@beijingair"]
category_18=["dust"]
category_19=["bed bugs"]

# %%
MONGO_HOST= 'mongodb://localhost/twitterdb'  # assuming you have mongoDB installed locally
                                             # and a database called 'twitterdb'
WORDS = ["#airpollution","air pollution",# original
        ,# category 1
                            ,# category 2 
                             # category 3
                            "earthquake",# category 4
                            ,
                           ,
                           ,
                           "allergy","allergins","pollen","dander", "allergy cough","pollen cough","allergins sneeze","pollen sneeze","pollen asthma","dander asthma"
,"dust respiratory","allegy lung"]
 
 
    class StreamListener(tweepy.StreamListener):    
        #This is a class provided by tweepy to access the Twitter Streaming API. 

        def on_connect(self):
            # Called initially to connect to the Streaming API
            print("You are now connected to the streaming API.")

        def on_error(self, status_code):
            # On error - if an error occurs, display the error / status code
            print('An Error has occured: ' + repr(status_code))
            return False

        def on_data(self, data):
            #This is the meat of the script...it connects to your mongoDB and stores the tweet
            try:
                client = MongoClient(MONGO_HOST)

                # Use twitterdb database. If it doesn't exist, it will be created.
                db = client.twitterdb

                # Decode the JSON from Twitter
                datajson = json.loads(data)

                #grab the 'created_at' data from the Tweet to use for display
                created_at = datajson['created_at']

                #print out a message to the screen that we have collected a tweet
                print("Tweet collected at " + str(created_at))

                #insert the data into the mongoDB into a collection called twitter_search
                #if twitter_search doesn't exist, it will be created.
                db.twitter_search.insert(datajson)
            except Exception as e:
                print(e)

        auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        #Set up the listener. The 'wait_on_rate_limit=True' is needed to help with Twitter API rate limiting.
        listener = StreamListener(api=tweepy.API(wait_on_rate_limit=True)) 
        streamer = tweepy.Stream(auth=auth, listener=listener)
        print("Tracking: " + str(WORDS))
        streamer.filter(track=WORDS)

# %%
help(tweepy.Stream.filter)
# Out:
# Help on function filter in module tweepy.streaming:
#
# filter(self, follow=None, track=None, async=False, locations=None, stall_warnings=False, languages=None, encoding='utf8', filter_level=None)

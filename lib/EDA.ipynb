# %%
import os
import pandas as pd

# %%
os.listdir('data/largefile/IAMR73')
# Out:
# ['IAIR73.DOC',
#  'IAMR73.DCF',
#  'IAMR73.DTA',
#  'IAMR73.FRQ',
#  'IAMR73.FRW',
#  'IAMR73.MAP']

# %%
itr = pd.read_stata('data/largefile/IAMR73/IAMR73.DTA', chunksize=100000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-dfa9473f9b48> in <module>()
# ----> 1 itr = pd.read_stata('data/largefile/IAMR73/IAMR73.DTA', chunksize=100000)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\stata.py in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, encoding, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator)
#     172                          columns=columns,
#     173                          order_categoricals=order_categoricals,
# --> 174                          chunksize=chunksize, encoding=encoding)
#     175
#     176     if iterator or chunksize:
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\stata.py in __init__(self, path_or_buf, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, encoding, chunksize)
#    1002             self.path_or_buf = BytesIO(contents)
#    1003
# -> 1004         self._read_header()
#    1005         self._setup_dtype()
#    1006
#
# ~\Anaconda3\lib\site-packages\pandas\io\stata.py in _read_header(self)
#    1025             self._read_new_header(first_char)
#    1026         else:
# -> 1027             self._read_old_header(first_char)
#    1028
#    1029         self.has_string_data = len([x for x in self.typlist
#
# ~\Anaconda3\lib\site-packages\pandas\io\stata.py in _read_old_header(self, first_char)
#    1224         self.format_version = struct.unpack('b', first_char)[0]
#    1225         if self.format_version not in [104, 105, 108, 111, 113, 114, 115]:
# -> 1226             raise ValueError(_version_error)
#    1227         self.byteorder = struct.unpack('b', self.path_or_buf.read(1))[
#    1228             0] == 0x1 and '>' or '<'
#
# ValueError: Version of given Stata file is not 104, 105, 108, 111 (Stata 7SE), 113 (Stata 8/9), 114 (Stata 10/11), 115 (Stata 12), 117 (Stata 13), or 118 (Stata 14)

# %% [markdown]
# # present data as is

# %%
itr.nvar # number of variables
# Out:
# 428

# %%
itr.nobs # number of rows
# Out:
# 2869043

# %%
list(itr.variable_labels().items())[0:20] # how does these variables look like
# Out:
# [('hhid', 'case identification'),
#  ('hvidx', 'line number'),
#  ('hv000', 'country code and phase'),
#  ('hv001', 'cluster number'),
#  ('hv002', 'household number'),
#  ('hv003', "respondent's line number (answering household questionnaire)"),
#  ('hv004', 'ultimate area unit'),
#  ('hv005', 'household sample weight (6 decimals)'),
#  ('hv006', 'month of interview'),
#  ('hv007', 'year of interview'),
#  ('hv008', 'date of interview (cmc)'),
#  ('hv009', 'number of household members'),
#  ('hv010', 'number of eligible women in household'),
#  ('hv011', 'number of eligible men in household'),
#  ('hv012', 'number of de jure members'),
#  ('hv013', 'number of de facto members'),
#  ('hv014', 'number of children 5 and under (de jure)'),
#  ('hv015', 'result of household interview'),
#  ('hv016', 'day of interview'),
#  ('hv017', 'number of visits')]

# %%
# categorical value description

# %%
list(itr.value_labels().items())[0:3]
# Out:
# [('HV003', {0: 'incomplete household'}),
#  ('HV015',
#   {1: 'completed',
#    2: 'no household member/no competent member at home',
#    3: 'entire household absent for extended period of time',
#    4: 'postponed',
#    5: 'refused',
#    6: 'dwelling vacant or address not a dwelling',
#    7: 'dwelling destroyed',
#    8: 'dwelling not found',
#    9: 'other'}),
#  ('HV020', {0: 'all woman sample', 1: 'ever married sample'})]

# %% [markdown]
# # load data by chunk

# %%
# set chunk size 
CHUNK_SIZE = 100000

# %%
itr = pd.read_stata('IAPR73FL.DTA', chunksize=CHUNK_SIZE)

# %%
itr.get_chunk().shape # it might take a while
# Out:
# (100000, 428)

# %%
first_batch=itr.get_chunk()

# %%
first_batch.head(10)
# Out:
#              hhid  hvidx hv000  hv001  hv002 hv003  hv004  hv005  hv006  \
# 100000   03067731      3   IA6  30677     31     3    677  49000     11
# 100001   03067731      4   IA6  30677     31     3    677  49000     11
# 100002   03067734      1   IA6  30677     34     1    677  49000     11
# 100003   03067734      2   IA6  30677     34     1    677  49000     11
# 100004   03067737      1   IA6  30677     37     2    677  49000     11
# 100005   03067737      2   IA6  30677     37     2    677  49000     11
# 100006   03067737      3   IA6  30677     37     2    677  49000     11
# 100007   03067737      4   IA6  30677     37     2    677  49000     11
# 100008   03067737      5   IA6  30677     37     2    677  49000     11
# 100009   03067737      6   IA6  30677     37     2    677  49000     11
#
#         hv007  ...    hml32a  hml32b  hml32c  hml32d  hml32e  hml32f  hml32g  \
# 100000   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100001   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100002   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100003   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100004   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100005   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100006   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100007   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100008   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 100009   2016  ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        hml33  hml34  hml35
# 100000   NaN           NaN
# 100001   NaN           NaN
# 100002   NaN           NaN
# 100003   NaN           NaN
# 100004   NaN           NaN
# 100005   NaN           NaN
# 100006   NaN           NaN
# 100007   NaN           NaN
# 100008   NaN           NaN
# 100009   NaN           NaN
#
# [10 rows x 428 columns]

# %% [markdown]
# # rename variables

# %%
first_batch = first_batch.rename(columns=itr.variable_labels())
first_batch.head()
# Out:
#        case identification  line number country code and phase  \
# 100000            03067731            3                    IA6
# 100001            03067731            4                    IA6
# 100002            03067734            1                    IA6
# 100003            03067734            2                    IA6
# 100004            03067737            1                    IA6
#
#         cluster number  household number  \
# 100000           30677                31
# 100001           30677                31
# 100002           30677                34
# 100003           30677                34
# 100004           30677                37
#
#        respondent's line number (answering household questionnaire)  \
# 100000                                                  3
# 100001                                                  3
# 100002                                                  1
# 100003                                                  1
# 100004                                                  2
#
#         ultimate area unit  household sample weight (6 decimals)  \
# 100000                 677                                 49000
# 100001                 677                                 49000
# 100002                 677                                 49000
# 100003                 677                                 49000
# 100004                 677                                 49000
#
#         month of interview  year of interview  \
# 100000                  11               2016
# 100001                  11               2016
# 100002                  11               2016
# 100003                  11               2016
# 100004                  11               2016
#
#                       ...                  \
# 100000                ...
# 100001                ...
# 100002                ...
# 100003                ...
# 100004                ...
#
#         na - presence of species: falciparum (pf)  \
# 100000                                        NaN
# 100001                                        NaN
# 100002                                        NaN
# 100003                                        NaN
# 100004                                        NaN
#
#         na - presence of species: malariae (pm)  \
# 100000                                      NaN
# 100001                                      NaN
# 100002                                      NaN
# 100003                                      NaN
# 100004                                      NaN
#
#         na - presence of species: ovale (po)  \
# 100000                                   NaN
# 100001                                   NaN
# 100002                                   NaN
# 100003                                   NaN
# 100004                                   NaN
#
#         na - presence of species: vivax (pv)  na - presence of species: cs  \
# 100000                                   NaN                           NaN
# 100001                                   NaN                           NaN
# 100002                                   NaN                           NaN
# 100003                                   NaN                           NaN
# 100004                                   NaN                           NaN
#
#         na - presence of species: cs  na - presence of species: cs  \
# 100000                           NaN                           NaN
# 100001                           NaN                           NaN
# 100002                           NaN                           NaN
# 100003                           NaN                           NaN
# 100004                           NaN                           NaN
#
#        na - result of malaria measurement  bar code for blood smear sample  \
# 100000                                NaN
# 100001                                NaN
# 100002                                NaN
# 100003                                NaN
# 100004                                NaN
#
#         na - result of malaria rapid test
# 100000                                NaN
# 100001                                NaN
# 100002                                NaN
# 100003                                NaN
# 100004                                NaN
#
# [5 rows x 428 columns]

# %%
first_batch.to_csv("sample_IAPR73FL.csv")

# %% [markdown]
# # how many batch are there ?

# %%
itr.nobs/CHUNK_SIZE
# Out:
# 28.69043

# %%
# Further analysis

# %%
def do_something:
    pass

# %%
for chunk in itr:
    do_something(chunk)
